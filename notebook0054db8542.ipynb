# %%
import os
print(os.listdir("/kaggle/input"))
# Out:
# ['datasets', 'competitions']

# %%
import os

print("🔍 Finding ISIC 2024...")
print("=" * 50)

# Check all possible locations
locations = [
    "/kaggle/input/isic2024",
    "/kaggle/input/competitions/isic2024",
    "/kaggle/input/notebooks/isic2024",
    "/kaggle/working",
]

for loc in locations:
    if os.path.exists(loc):
        print(f"📁 Checking: {loc}")
        try:
            contents = os.listdir(loc)
            print(f"   Contents: {contents[:10]}")
        except:
            print("   (Cannot read)")

# Check what's in /kaggle/input
print("\n📁 All input directories:")
for item in os.listdir("/kaggle/input"):
    print(f"  {item}")
    item_path = os.path.join("/kaggle/input", item)
    if os.path.isdir(item_path):
        try:
            contents = os.listdir(item_path)
            print(f"    Contents: {contents[:3]}")
        except:
            pass
# Out:
# 🔍 Finding ISIC 2024...
# ...
# 📁 Checking: /kaggle/working
#    Contents: ['.virtual_documents']
#
# 📁 All input directories:
#   datasets
#     Contents: ['tomooinubushi', 'eliocordeiropereira']
#   competitions
#     Contents: []

# %%
import os

# The notebook is likely at this path
notebook_path = "/kaggle/input/notebooks/isic-2024"

if os.path.exists(notebook_path):
    print(f"✅ FOUND at: {notebook_path}")
    print(f"Contents: {os.listdir(notebook_path)}")
else:
    print("❌ Not found. Let me search:")
    # !find /kaggle -name "*isic*" -type d 2>/dev/null | head -10
# Out:
# ❌ Not found. Let me search:
# /kaggle/input/datasets/tomooinubushi/all-isic-data-20240629

# %%
import os
# The definitive path for competition data in a Kaggle notebook
data_path = '/kaggle/input/isic-2024/'
print(os.listdir(data_path))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_58/3525206485.py in <cell line: 0>()
#       2 # The definitive path for competition data in a Kaggle notebook
#       3 data_path = '/kaggle/input/isic-2024/'
# ----> 4 print(os.listdir(data_path))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/input/isic-2024/'

# %%
import os
print(os.listdir('/kaggle/input/isic-2024/'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_58/2908789217.py in <cell line: 0>()
#       1 import os
# ----> 2 print(os.listdir('/kaggle/input/isic-2024/'))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/input/isic-2024/'

# %%
import os
print("Folders inside /kaggle/input/ :")
print(os.listdir('/kaggle/input/'))
# Out:
# Folders inside /kaggle/input/ :
# ['datasets', 'competitions']

# %%
import os
print(os.listdir('/kaggle/input/'))
# Out:
# ['datasets', 'competitions']

# %%
import os
print(os.listdir('/kaggle/input'))
# Out:
# ['datasets', 'competitions']

# %%
import os

for sub in ['datasets', 'competitions']:
    path = f'/kaggle/input/{sub}'
    print(f"--- {path} ---")
    try:
        print(os.listdir(path))
    except Exception as e:
        print(f"Error: {e}")
# Out:
# --- /kaggle/input/datasets ---
# ['tomooinubushi', 'eliocordeiropereira']
# --- /kaggle/input/competitions ---
# []

# %%
script_path = "/kaggle/working/TrustworthyMed/src/run_experiment.py"

with open(script_path) as f:
    lines = f.readlines()

print("=== Lines 105-120 ===\n")
for i in range(104, min(120, len(lines))):
    print(f"Line {i+1}: {lines[i].rstrip()}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_59/3816457397.py in <cell line: 0>()
#       1 script_path = "/kaggle/working/TrustworthyMed/src/run_experiment.py"
#       2
# ----> 3 with open(script_path) as f:
#       4     lines = f.readlines()
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/working/TrustworthyMed/src/run_experiment.py'

# %%
import os

base = "/kaggle/working/TrustworthyMed"

if os.path.exists(base):
    print("✓ TrustworthyMed directory exists")
    for root, dirs, files in os.walk(base):
        level = root.replace(base, '').count(os.sep)
        indent = ' ' * 2 * level
        print(f"{indent}{os.path.basename(root)}/")
        subindent = ' ' * 2 * (level + 1)
        for f in files[:5]:  # limit output
            print(f"{subindent}{f}")
else:
    print("✗ TrustworthyMed directory MISSING — need to re-clone")
# Out:
# ✗ TrustworthyMed directory MISSING — need to re-clone
